# %%
#Run this cell
#Importing necessary libraries 
import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt
import json
ans=[None]*5

# %%
#Download Dataset from https://www.kaggle.com/uciml/zoo-animal-classification
data = pd.read_csv('zoo.csv')

# %%
data.head()
# Out:
#   animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0    aardvark     1         0     0     1         0        0         1
# 1    antelope     1         0     0     1         0        0         0
# 2        bass     0         0     1     0         0        1         1
# 3        bear     1         0     0     1         0        0         1
# 4        boar     1         0     0     1         0        0         1
#
#    toothed  backbone  breathes  venomous  fins  legs  tail  domestic  catsize  \
# 0        1         1         1         0     0     4     0         0        1
# 1        1         1         1         0     0     4     1         0        1
# 2        1         1         0         0     1     0     1         0        0
# 3        1         1         1         0     0     4     0         0        1
# 4        1         1         1         0     0     4     1         0        1
#
#    class_type
# 0           1
# 1           1
# 2           4
# 3           1
# 4           1

# %%
animals = pd.read_csv('class.csv')
animals.head()
# Out:
#    Class_Number  Number_Of_Animal_Species_In_Class Class_Type  \
# 0             1                                 41     Mammal
# 1             2                                 20       Bird
# 2             3                                  5    Reptile
# 3             4                                 13       Fish
# 4             5                                  4  Amphibian
#
#                                         Animal_Names
# 0  aardvark, antelope, bear, boar, buffalo, calf,...
# 1  chicken, crow, dove, duck, flamingo, gull, haw...
# 2    pitviper, seasnake, slowworm, tortoise, tuatara
# 3  bass, carp, catfish, chub, dogfish, haddock, h...
# 4                             frog, frog, newt, toad

# %%
#Import the dataset and define the feature as well as the target datasets / columns 
X = data.loc[:, data.columns != 'class_type']
y = data.loc[:, data.columns == 'class_type']
#We drop the animal names since this is not a good feature to split the data on  
X = X.loc[:, X.columns != 'animal_name']
X = np.array(X)
y = np.array(y)

# %%
#Write a function to find the entropy on a split "target_col"
def entropy(target_col):
    #target column as a pandas dataframe is taken as an argument
    vals={}
    col = np.array(target_col)
    col = col.ravel()
    l = col.size
    a = []
    size=0
    for val in col:
        if val in vals.keys():
            a[vals[val]] = a[vals[val]]+1
        else:
            vals[val] = size
            a.append(1)
            size = size+1
    a = np.array(a)
    a = a/l
    log_array = np.log2(a)
    g = np.multiply(log_array, a)
    res = -np.sum(g)
    return res

# %%
#Save all the feature names in an array "feature names"
feature_names=['hair','feathers','eggs','milk','airborne','aquatic','predator','toothed','backbone', 
               'breathes','venomous','fins','legs','tail','domestic','catsize']
#Find the entropy of all the features in the dataset
entropy_value = {}
for feature in feature_names:
    column = data.loc[:, data.columns == feature]
    entropy_value[feature] = entropy(column)
print(entropy_value)
# Out:
# {'hair': 0.9840304711717018, 'feathers': 0.7179499765002912, 'eggs': 0.9794662187017298, 'milk': 0.9743197211096903, 'airborne': 0.7910662980902585, 'aquatic': 0.9396846718728562, 'predator': 0.9914266810680206, 'toothed': 0.9685867165455516, 'backbone': 0.6761627418829198, 'breathes': 0.7374895672137456, 'venomous': 0.3993820824245975, 'fins': 0.653839880626333, 'legs': 2.0338113440641234, 'tail': 0.8228368841492257, 'domestic': 0.5538976334852962, 'catsize': 0.9880162151534646}

# %%
#Find the entropy of the feature "toothed"
ans[0]=entropy_value["toothed"]

# %%
#Write a function to calculate Information Gain on a split attribute and a target column
def InfoGain(data,split_attribute_name,target_name="class"):       
    #Calculate the entropy of the total dataset  
    col = data.loc[:, data.columns == split_attribute_name]
    target = data.loc[:, data.columns == target_name]
    original_entropy = entropy(target)
    #Calculate the values and the corresponding counts for the split attribute   
    split = {}
    split_count = {}
    array_col = np.array(col).ravel()
    array_target = np.array(target).ravel()
    total_size = array_col.size
    i=0
    for attribute in array_col:
        if attribute in split.keys():
            split[attribute].append(array_target[i])
        else:
            a = []
            split[attribute] = a
            split[attribute].append(array_target[i])
            split_count[attribute] = 0
        i=i+1
        split_count[attribute] = split_count[attribute] + 1
    #Calculate the weighted entropy 
    entropies = []
    weights = []
    for attribute in split:
        df = pd.DataFrame(split[attribute])
        entropies.append(entropy(df))
        weights.append(split_count[attribute]/total_size)
    entropies = np.array(entropies)
    weights = np.array(weights)
    weighted_entropies = np.multiply(entropies, weights)
    #Calculate the information gain  
    info_gain = original_entropy - np.sum(weighted_entropies)
    return info_gain

# %%
#Find the information gain having split attribute "hair" and the target feature name "milk"
ans[1]=InfoGain(data, "hair", "milk")

# %%
#Find the Info gain having "milk" as the split attribute and all the other features as target features one at a time
IG = {}
for target in feature_names:
    if target == 'milk':
        continue
    else:
        IG[target] = InfoGain(data, "milk", target)
for target in IG:
    print("Information Gain taking milk as split attribute and {target_name} as target feature = {val}".format(target_name = target, val = IG[target]))
# Out:
# Information Gain taking milk as split attribute and hair as target feature = 0.6599660577558698
# Information Gain taking milk as split attribute and feathers as target feature = 0.17242769884415887
# Information Gain taking milk as split attribute and eggs as target feature = 0.7870598185734241
# Information Gain taking milk as split attribute and airborne as target feature = 0.11370352314621812
# Information Gain taking milk as split attribute and aquatic as target feature = 0.10181386403185955
# Information Gain taking milk as split attribute and predator as target feature = 0.0006367772440212249
# Information Gain taking milk as split attribute and toothed as target feature = 0.3465412540071715
# Information Gain taking milk as split attribute and backbone as target feature = 0.15262359382508262
# Information Gain taking milk as split attribute and breathes as target feature = 0.18259765312929555
# Information Gain taking milk as split attribute and venomous as target feature = 0.06284178150207947
# Information Gain taking milk as split attribute and fins as target feature = 0.018672543666944486
# Information Gain taking milk as split attribute and legs as target feature = 0.36709133269262484
# Information Gain taking milk as split attribute and tail as target feature = 0.03350320459269063
# Information Gain taking milk as split attribute and domestic as target feature = 0.01901013577509325
# Information Gain taking milk as split attribute and catsize as target feature = 0.2509271768405701

# %%
#Import Decision Tree Classifier from sklearn
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
#Split the given data into 80 percent training data and 20 percent testing data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
#Fit the given data
X_train = np.array(X_train)
y_train = np.array(y_train)
tree = DecisionTreeClassifier()
tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Make a prediction on the test data and return the percentage of accuracy
from sklearn.metrics import accuracy_score
X_test =  np.array(X_test)
y_test = np.array(y_test)
y_pred = tree.predict(X_test)
ans[2]=accuracy_score(y_test, y_pred)*100
# Out:
# 100.0

# %%
#Run this cell to visualize the decision tree
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

dot_data = StringIO()
export_graphviz(tree, out_file=dot_data, feature_names=feature_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Input In [119], in <module>
#       8 export_graphviz(tree, out_file=dot_data, feature_names=feature_names,
#       9                 filled=True, rounded=True,
#      10                 special_characters=True)
#      11 graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# ---> 12 Image(graph.create_png())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydotplus\graphviz.py:1797, in Dot.__init__.<locals>.<lambda>(f, prog)
#    1792 # Automatically creates all the methods enabling the creation
#    1793 # of output in any of the supported formats.
#    1794 for frmt in self.formats:
#    1795     self.__setattr__(
#    1796         'create_' + frmt,
# -> 1797         lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798     )
#    1799     f = self.__dict__['create_' + frmt]
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found

# %%
#Use sklearn to make a classification report and a confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
cr = classification_report(y_pred, y_test)
cm = confusion_matrix(y_test, y_pred)

# %%
#Find the recall,f1-score for class type '3'
from sklearn.metrics import f1_score
recall_3 =  
ans[3]=

# %%
#Calculate Mean Absolute Error,Mean Squared Error and Root Mean Squared Error
...
...
...

# %%
#Find the mean absolute error and root mean square error, save then in a list [mae,rmse]
ans[4]=

# %%
ans = [item for item in ans]
with open('ans.json', 'w') as f:
    json.dump(ans, f)
! ~/submit

# %%
pip install sklearn

# %%
pip install --upgrade pip

# %%
pip install sklearn

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.1-cp310-cp310-win_amd64.whl (8.3 MB)
#      ---------------------------------------- 8.3/8.3 MB 4.0 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting scipy>=1.3.2
#   Downloading scipy-1.10.0-cp310-cp310-win_amd64.whl (42.5 MB)
#      ---------------------------------------- 42.5/42.5 MB 4.5 MB/s eta 0:00:00
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 298.0/298.0 kB 4.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.22.2)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 scipy-1.10.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install six
# Out:
# Requirement already satisfied: six in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install --upgrade scikit-learn==0.20.3
# Out:
# Collecting scikit-learn==0.20.3
#   Downloading scikit-learn-0.20.3.tar.gz (11.8 MB)
#      ---------------------------------------- 11.8/11.8 MB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.8.2 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==0.20.3) (1.22.2)
# Requirement already satisfied: scipy>=0.13.3 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn==0.20.3) (1.10.0)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.1
#     Uninstalling scikit-learn-1.2.1:
#       Successfully uninstalled scikit-learn-1.2.1
#   Running setup.py install for scikit-learn: started
#   Running setup.py install for scikit-learn: finished with status 'error'
#   Rolling back uninstall of scikit-learn
#   Moving to c:\users\user\appdata\local\programs\python\python310\lib\site-packages\scikit_learn-1.2.1.dist-info\
#    from C:\Users\User\AppData\Local\Programs\Python\Python310\Lib\site-packages\~cikit_learn-1.2.1.dist-info
#   Moving to c:\users\user\appdata\local\programs\python\python310\lib\site-packages\sklearn\
#    from C:\Users\User\AppData\Local\Programs\Python\Python310\Lib\site-packages\~klearn
#   DEPRECATION: scikit-learn is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   error: subprocess-exited-with-error
#
#   Running setup.py install for scikit-learn did not run successfully.
#   exit code: 1
#
#   [682 lines of output]
#   Partial import of sklearn during the build process.
#   INFO: blas_opt_info:
#   INFO: blas_armpl_info:
#   INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   INFO: customize MSVCCompiler
#   INFO:   libraries armpl_lp64_mp not found in ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blas_mkl_info:
#   INFO:   libraries mkl_rt not found in ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: blis_info:
#   INFO:   libraries blis not found in ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: openblas_info:
#   INFO:   libraries openblas not found in ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   INFO: get_default_fcompiler: matching types: '['gnu', 'intelv', 'absoft', 'compaqv', 'intelev', 'gnu95', 'g95', 'intelvem', 'intelem', 'flang']'
#   INFO: customize GnuFCompiler
#   WARN: Could not locate executable g77
#   WARN: Could not locate executable f77
#   INFO: customize IntelVisualFCompiler
#   WARN: Could not locate executable ifort
#   WARN: Could not locate executable ifl
#   INFO: customize AbsoftFCompiler
#   WARN: Could not locate executable f90
#   INFO: customize CompaqVisualFCompiler
#   WARN: Could not locate executable DF
#   INFO: customize IntelItaniumVisualFCompiler
#   WARN: Could not locate executable efl
#   INFO: customize Gnu95FCompiler
#   WARN: Could not locate executable gfortran
#   WARN: Could not locate executable f95
#   INFO: customize G95FCompiler
#   WARN: Could not locate executable g95
#   INFO: customize IntelEM64VisualFCompiler
#   INFO: customize IntelEM64TFCompiler
#   WARN: Could not locate executable efort
#   WARN: Could not locate executable efc
#   INFO: customize PGroupFlangCompiler
#   WARN: Could not locate executable flang
#   WARN: don't know how to compile Fortran code on platform 'nt'
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: accelerate_info:
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_3_10_blas_threads_info:
#   INFO: Setting PTATLAS=ATLAS
#   INFO:   libraries tatlas not found in ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_3_10_blas_info:
#   INFO:   libraries satlas not found in ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_blas_threads_info:
#   INFO: Setting PTATLAS=ATLAS
#   INFO:   libraries ptf77blas,ptcblas,atlas not found in ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   INFO: atlas_blas_info:
#   INFO:   libraries f77blas,cblas,atlas not found in ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\distutils\system_info.py:2077: UserWarning:
#       Optimized (vendor) Blas libraries are not found.
#       Falls back to netlib Blas library which has worse performance.
#       A better performance should be easily gained by switching
#       Blas library.
#     if self._calc_info(blas):
#   INFO: blas_info:
#   INFO:   libraries blas not found in ['C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\lib', 'C:\\', 'C:\\Users\\User\\AppData\\Local\\Programs\\Python\\Python310\\libs']
#   INFO:   NOT AVAILABLE
#   INFO:
#   C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\distutils\system_info.py:2077: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     if self._calc_info(blas):
#   INFO: blas_src_info:
#   INFO:   NOT AVAILABLE
#   INFO:
#   C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\distutils\system_info.py:2077: UserWarning:
#       Blas (http://www.netlib.org/blas/) sources not found.
#       Directories to search for the sources can be specified in the
#       numpy/distutils/site.cfg file (section [blas_src]) or by setting
#       the BLAS_SRC environment variable.
#     if self._calc_info(blas):
#   INFO:   NOT AVAILABLE
#   INFO:
#   C:\Users\User\AppData\Local\Temp\pip-install-tkl58ecs\scikit-learn_d4f8ac20f4804a1fa2ee8f26b8428238\sklearn\setup.py:73: UserWarning:
#       Blas (http://www.netlib.org/blas/) libraries not found.
#       Directories to search for the libraries can be specified in the
#       numpy/distutils/site.cfg file (section [blas]) or by setting
#       the BLAS environment variable.
#     warnings.warn(BlasNotFoundError.__doc__)
#   running install
#   running build
#   running config_cc
#   INFO: unifing config_cc, config, build_clib, build_ext, build commands --compiler options
#   running config_fc
#   INFO: unifing config_fc, config, build_clib, build_ext, build commands --fcompiler options
#   running build_src
#   INFO: build_src
#   INFO: building library "libsvm-skl" sources
#   INFO: building library "cblas" sources
#   INFO: building extension "sklearn.__check_build._check_build" sources
#   INFO: building extension "sklearn.cluster._dbscan_inner" sources
#   INFO: building extension "sklearn.cluster._hierarchical" sources
#   INFO: building extension "sklearn.cluster._k_means_elkan" sources
#   INFO: building extension "sklearn.cluster._k_means" sources
#   INFO: building extension "sklearn.datasets._svmlight_format" sources
#   INFO: building extension "sklearn.decomposition._online_lda" sources
#   INFO: building extension "sklearn.decomposition.cdnmf_fast" sources
#   INFO: building extension "sklearn.ensemble._gradient_boosting" sources
#   INFO: building extension "sklearn.feature_extraction._hashing" sources
#   INFO: building extension "sklearn.manifold._utils" sources
#   INFO: building extension "sklearn.manifold._barnes_hut_tsne" sources
#   INFO: building extension "sklearn.metrics.cluster.expected_mutual_info_fast" sources
#   INFO: building extension "sklearn.metrics.pairwise_fast" sources
#   INFO: building extension "sklearn.neighbors.ball_tree" sources
#   INFO: building extension "sklearn.neighbors.kd_tree" sources
#   INFO: building extension "sklearn.neighbors.dist_metrics" sources
#   INFO: building extension "sklearn.neighbors.typedefs" sources
#   INFO: building extension "sklearn.neighbors.quad_tree" sources
#   INFO: building extension "sklearn.tree._tree" sources
#   INFO: building extension "sklearn.tree._splitter" sources
#   INFO: building extension "sklearn.tree._criterion" sources
#   INFO: building extension "sklearn.tree._utils" sources
#   INFO: building extension "sklearn.svm.libsvm" sources
#   INFO: building extension "sklearn.svm.liblinear" sources
#   INFO: building extension "sklearn.svm.libsvm_sparse" sources
#   INFO: building extension "sklearn._isotonic" sources
#   INFO: building extension "sklearn.linear_model.cd_fast" sources
#   INFO: building extension "sklearn.linear_model.sgd_fast" sources
#   INFO: building extension "sklearn.linear_model.sag_fast" sources
#   INFO: building extension "sklearn.utils.sparsefuncs_fast" sources
#   INFO: building extension "sklearn.utils.arrayfuncs" sources
#   INFO: building extension "sklearn.utils.murmurhash" sources
#   INFO: building extension "sklearn.utils.lgamma" sources
#   INFO: building extension "sklearn.utils.graph_shortest_path" sources
#   INFO: building extension "sklearn.utils.fast_dict" sources
#   INFO: building extension "sklearn.utils.seq_dataset" sources
#   INFO: building extension "sklearn.utils.weight_vector" sources
#   INFO: building extension "sklearn.utils._random" sources
#   INFO: building extension "sklearn.utils._logistic_sigmoid" sources
#   INFO: building data_files sources
#   INFO: build_src: building npy-pkg config files
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.10
#   creating build\lib.win-amd64-3.10\sklearn
#   copying sklearn\base.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\calibration.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\discriminant_analysis.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\dummy.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\exceptions.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\impute.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\isotonic.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\kernel_approximation.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\kernel_ridge.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\multiclass.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\multioutput.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\naive_bayes.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\pipeline.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\random_projection.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\setup.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\_config.py -> build\lib.win-amd64-3.10\sklearn
#   copying sklearn\__init__.py -> build\lib.win-amd64-3.10\sklearn
#   creating build\lib.win-amd64-3.10\sklearn\__check_build
#   copying sklearn\__check_build\setup.py -> build\lib.win-amd64-3.10\sklearn\__check_build
#   copying sklearn\__check_build\__init__.py -> build\lib.win-amd64-3.10\sklearn\__check_build
#   creating build\lib.win-amd64-3.10\sklearn\_build_utils
#   copying sklearn\_build_utils\__init__.py -> build\lib.win-amd64-3.10\sklearn\_build_utils
#   creating build\lib.win-amd64-3.10\sklearn\compose
#   copying sklearn\compose\_column_transformer.py -> build\lib.win-amd64-3.10\sklearn\compose
#   copying sklearn\compose\_target.py -> build\lib.win-amd64-3.10\sklearn\compose
#   copying sklearn\compose\__init__.py -> build\lib.win-amd64-3.10\sklearn\compose
#   creating build\lib.win-amd64-3.10\sklearn\compose\tests
#   copying sklearn\compose\tests\test_column_transformer.py -> build\lib.win-amd64-3.10\sklearn\compose/tests
#   copying sklearn\compose\tests\test_target.py -> build\lib.win-amd64-3.10\sklearn\compose/tests
#   copying sklearn\compose\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\compose/tests
#   creating build\lib.win-amd64-3.10\sklearn\covariance
#   copying sklearn\covariance\elliptic_envelope.py -> build\lib.win-amd64-3.10\sklearn\covariance
#   copying sklearn\covariance\empirical_covariance_.py -> build\lib.win-amd64-3.10\sklearn\covariance
#   copying sklearn\covariance\graph_lasso_.py -> build\lib.win-amd64-3.10\sklearn\covariance
#   copying sklearn\covariance\robust_covariance.py -> build\lib.win-amd64-3.10\sklearn\covariance
#   copying sklearn\covariance\shrunk_covariance_.py -> build\lib.win-amd64-3.10\sklearn\covariance
#   copying sklearn\covariance\__init__.py -> build\lib.win-amd64-3.10\sklearn\covariance
#   creating build\lib.win-amd64-3.10\sklearn\covariance\tests
#   copying sklearn\covariance\tests\test_covariance.py -> build\lib.win-amd64-3.10\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_elliptic_envelope.py -> build\lib.win-amd64-3.10\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_graphical_lasso.py -> build\lib.win-amd64-3.10\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_graph_lasso.py -> build\lib.win-amd64-3.10\sklearn\covariance/tests
#   copying sklearn\covariance\tests\test_robust_covariance.py -> build\lib.win-amd64-3.10\sklearn\covariance/tests
#   copying sklearn\covariance\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\covariance/tests
#   creating build\lib.win-amd64-3.10\sklearn\cross_decomposition
#   copying sklearn\cross_decomposition\cca_.py -> build\lib.win-amd64-3.10\sklearn\cross_decomposition
#   copying sklearn\cross_decomposition\pls_.py -> build\lib.win-amd64-3.10\sklearn\cross_decomposition
#   copying sklearn\cross_decomposition\__init__.py -> build\lib.win-amd64-3.10\sklearn\cross_decomposition
#   creating build\lib.win-amd64-3.10\sklearn\cross_decomposition\tests
#   copying sklearn\cross_decomposition\tests\test_pls.py -> build\lib.win-amd64-3.10\sklearn\cross_decomposition/tests
#   copying sklearn\cross_decomposition\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\cross_decomposition/tests
#   creating build\lib.win-amd64-3.10\sklearn\feature_selection
#   copying sklearn\feature_selection\base.py -> build\lib.win-amd64-3.10\sklearn\feature_selection
#   copying sklearn\feature_selection\from_model.py -> build\lib.win-amd64-3.10\sklearn\feature_selection
#   copying sklearn\feature_selection\mutual_info_.py -> build\lib.win-amd64-3.10\sklearn\feature_selection
#   copying sklearn\feature_selection\rfe.py -> build\lib.win-amd64-3.10\sklearn\feature_selection
#   copying sklearn\feature_selection\univariate_selection.py -> build\lib.win-amd64-3.10\sklearn\feature_selection
#   copying sklearn\feature_selection\variance_threshold.py -> build\lib.win-amd64-3.10\sklearn\feature_selection
#   copying sklearn\feature_selection\__init__.py -> build\lib.win-amd64-3.10\sklearn\feature_selection
#   creating build\lib.win-amd64-3.10\sklearn\feature_selection\tests
#   copying sklearn\feature_selection\tests\test_base.py -> build\lib.win-amd64-3.10\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_chi2.py -> build\lib.win-amd64-3.10\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_feature_select.py -> build\lib.win-amd64-3.10\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_from_model.py -> build\lib.win-amd64-3.10\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_mutual_info.py -> build\lib.win-amd64-3.10\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_rfe.py -> build\lib.win-amd64-3.10\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\test_variance_threshold.py -> build\lib.win-amd64-3.10\sklearn\feature_selection/tests
#   copying sklearn\feature_selection\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\feature_selection/tests
#   creating build\lib.win-amd64-3.10\sklearn\gaussian_process
#   copying sklearn\gaussian_process\correlation_models.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process
#   copying sklearn\gaussian_process\gpc.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process
#   copying sklearn\gaussian_process\gpr.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process
#   copying sklearn\gaussian_process\kernels.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process
#   copying sklearn\gaussian_process\regression_models.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process
#   copying sklearn\gaussian_process\__init__.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process
#   creating build\lib.win-amd64-3.10\sklearn\gaussian_process\tests
#   copying sklearn\gaussian_process\tests\test_gpc.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\test_gpr.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\test_kernels.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process/tests
#   copying sklearn\gaussian_process\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\gaussian_process/tests
#   creating build\lib.win-amd64-3.10\sklearn\mixture
#   copying sklearn\mixture\base.py -> build\lib.win-amd64-3.10\sklearn\mixture
#   copying sklearn\mixture\bayesian_mixture.py -> build\lib.win-amd64-3.10\sklearn\mixture
#   copying sklearn\mixture\gaussian_mixture.py -> build\lib.win-amd64-3.10\sklearn\mixture
#   copying sklearn\mixture\__init__.py -> build\lib.win-amd64-3.10\sklearn\mixture
#   creating build\lib.win-amd64-3.10\sklearn\mixture\tests
#   copying sklearn\mixture\tests\test_bayesian_mixture.py -> build\lib.win-amd64-3.10\sklearn\mixture/tests
#   copying sklearn\mixture\tests\test_gaussian_mixture.py -> build\lib.win-amd64-3.10\sklearn\mixture/tests
#   copying sklearn\mixture\tests\test_mixture.py -> build\lib.win-amd64-3.10\sklearn\mixture/tests
#   copying sklearn\mixture\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\mixture/tests
#   creating build\lib.win-amd64-3.10\sklearn\model_selection
#   copying sklearn\model_selection\_search.py -> build\lib.win-amd64-3.10\sklearn\model_selection
#   copying sklearn\model_selection\_split.py -> build\lib.win-amd64-3.10\sklearn\model_selection
#   copying sklearn\model_selection\_validation.py -> build\lib.win-amd64-3.10\sklearn\model_selection
#   copying sklearn\model_selection\__init__.py -> build\lib.win-amd64-3.10\sklearn\model_selection
#   creating build\lib.win-amd64-3.10\sklearn\model_selection\tests
#   copying sklearn\model_selection\tests\common.py -> build\lib.win-amd64-3.10\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\test_search.py -> build\lib.win-amd64-3.10\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\test_split.py -> build\lib.win-amd64-3.10\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\test_validation.py -> build\lib.win-amd64-3.10\sklearn\model_selection/tests
#   copying sklearn\model_selection\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\model_selection/tests
#   creating build\lib.win-amd64-3.10\sklearn\neural_network
#   copying sklearn\neural_network\multilayer_perceptron.py -> build\lib.win-amd64-3.10\sklearn\neural_network
#   copying sklearn\neural_network\rbm.py -> build\lib.win-amd64-3.10\sklearn\neural_network
#   copying sklearn\neural_network\_base.py -> build\lib.win-amd64-3.10\sklearn\neural_network
#   copying sklearn\neural_network\_stochastic_optimizers.py -> build\lib.win-amd64-3.10\sklearn\neural_network
#   copying sklearn\neural_network\__init__.py -> build\lib.win-amd64-3.10\sklearn\neural_network
#   creating build\lib.win-amd64-3.10\sklearn\neural_network\tests
#   copying sklearn\neural_network\tests\test_mlp.py -> build\lib.win-amd64-3.10\sklearn\neural_network/tests
#   copying sklearn\neural_network\tests\test_rbm.py -> build\lib.win-amd64-3.10\sklearn\neural_network/tests
#   copying sklearn\neural_network\tests\test_stochastic_optimizers.py -> build\lib.win-amd64-3.10\sklearn\neural_network/tests
#   copying sklearn\neural_network\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\neural_network/tests
#   creating build\lib.win-amd64-3.10\sklearn\preprocessing
#   copying sklearn\preprocessing\base.py -> build\lib.win-amd64-3.10\sklearn\preprocessing
#   copying sklearn\preprocessing\data.py -> build\lib.win-amd64-3.10\sklearn\preprocessing
#   copying sklearn\preprocessing\imputation.py -> build\lib.win-amd64-3.10\sklearn\preprocessing
#   copying sklearn\preprocessing\label.py -> build\lib.win-amd64-3.10\sklearn\preprocessing
#   copying sklearn\preprocessing\_discretization.py -> build\lib.win-amd64-3.10\sklearn\preprocessing
#   copying sklearn\preprocessing\_encoders.py -> build\lib.win-amd64-3.10\sklearn\preprocessing
#   copying sklearn\preprocessing\_function_transformer.py -> build\lib.win-amd64-3.10\sklearn\preprocessing
#   copying sklearn\preprocessing\__init__.py -> build\lib.win-amd64-3.10\sklearn\preprocessing
#   creating build\lib.win-amd64-3.10\sklearn\preprocessing\tests
#   copying sklearn\preprocessing\tests\test_base.py -> build\lib.win-amd64-3.10\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_common.py -> build\lib.win-amd64-3.10\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_data.py -> build\lib.win-amd64-3.10\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_discretization.py -> build\lib.win-amd64-3.10\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_encoders.py -> build\lib.win-amd64-3.10\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_function_transformer.py -> build\lib.win-amd64-3.10\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_imputation.py -> build\lib.win-amd64-3.10\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\test_label.py -> build\lib.win-amd64-3.10\sklearn\preprocessing/tests
#   copying sklearn\preprocessing\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\preprocessing/tests
#   creating build\lib.win-amd64-3.10\sklearn\semi_supervised
#   copying sklearn\semi_supervised\label_propagation.py -> build\lib.win-amd64-3.10\sklearn\semi_supervised
#   copying sklearn\semi_supervised\__init__.py -> build\lib.win-amd64-3.10\sklearn\semi_supervised
#   creating build\lib.win-amd64-3.10\sklearn\semi_supervised\tests
#   copying sklearn\semi_supervised\tests\test_label_propagation.py -> build\lib.win-amd64-3.10\sklearn\semi_supervised/tests
#   copying sklearn\semi_supervised\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\semi_supervised/tests
#   creating build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\affinity_propagation_.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\bicluster.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\birch.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\dbscan_.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\hierarchical.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\k_means_.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\mean_shift_.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\setup.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\spectral.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\_feature_agglomeration.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   copying sklearn\cluster\__init__.py -> build\lib.win-amd64-3.10\sklearn\cluster
#   creating build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\common.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_affinity_propagation.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_bicluster.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_birch.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_dbscan.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_feature_agglomeration.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_hierarchical.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_k_means.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_mean_shift.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\test_spectral.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   copying sklearn\cluster\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\cluster\tests
#   creating build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\base.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\california_housing.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\covtype.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\kddcup99.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\lfw.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\mlcomp.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\mldata.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\olivetti_faces.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\openml.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\rcv1.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\samples_generator.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\setup.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\species_distributions.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\svmlight_format.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\twenty_newsgroups.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   copying sklearn\datasets\__init__.py -> build\lib.win-amd64-3.10\sklearn\datasets
#   creating build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_20news.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_base.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_california_housing.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_common.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_covtype.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_kddcup99.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_lfw.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_mldata.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_openml.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_rcv1.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_samples_generator.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\test_svmlight_format.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   copying sklearn\datasets\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\datasets\tests
#   creating build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\base.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\dict_learning.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\factor_analysis.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\fastica_.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\incremental_pca.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\kernel_pca.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\nmf.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\online_lda.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\pca.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\setup.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\sparse_pca.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\truncated_svd.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   copying sklearn\decomposition\__init__.py -> build\lib.win-amd64-3.10\sklearn\decomposition
#   creating build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_dict_learning.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_factor_analysis.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_fastica.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_incremental_pca.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_kernel_pca.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_nmf.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_online_lda.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_pca.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_sparse_pca.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\test_truncated_svd.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   copying sklearn\decomposition\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\decomposition\tests
#   creating build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\bagging.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\base.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\forest.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\gradient_boosting.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\iforest.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\partial_dependence.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\setup.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\voting_classifier.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\weight_boosting.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   copying sklearn\ensemble\__init__.py -> build\lib.win-amd64-3.10\sklearn\ensemble
#   creating build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_bagging.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_base.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_forest.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_gradient_boosting.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_gradient_boosting_loss_functions.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_iforest.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_partial_dependence.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_voting_classifier.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\test_weight_boosting.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   copying sklearn\ensemble\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\ensemble\tests
#   creating build\lib.win-amd64-3.10\sklearn\externals
#   copying sklearn\externals\conftest.py -> build\lib.win-amd64-3.10\sklearn\externals
#   copying sklearn\externals\funcsigs.py -> build\lib.win-amd64-3.10\sklearn\externals
#   copying sklearn\externals\setup.py -> build\lib.win-amd64-3.10\sklearn\externals
#   copying sklearn\externals\six.py -> build\lib.win-amd64-3.10\sklearn\externals
#   copying sklearn\externals\_arff.py -> build\lib.win-amd64-3.10\sklearn\externals
#   copying sklearn\externals\_pilutil.py -> build\lib.win-amd64-3.10\sklearn\externals
#   copying sklearn\externals\__init__.py -> build\lib.win-amd64-3.10\sklearn\externals
#   creating build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\backports.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\compressor.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\disk.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\executor.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\format_stack.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\func_inspect.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\hashing.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\logger.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\memory.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\my_exceptions.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle_compat.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\numpy_pickle_utils.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\parallel.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\pool.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\testing.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_compat.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_dask.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_memmapping_reducer.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_memory_helpers.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_multiprocessing_helpers.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_parallel_backends.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\_store_backends.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   copying sklearn\externals\joblib\__init__.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib
#   creating build\lib.win-amd64-3.10\sklearn\externals\joblib\externals
#   copying sklearn\externals\joblib\externals\__init__.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals
#   creating build\lib.win-amd64-3.10\sklearn\externals\joblib\externals\loky
#   copying sklearn\externals\joblib\externals\loky\cloudpickle_wrapper.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky
#   copying sklearn\externals\joblib\externals\loky\process_executor.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky
#   copying sklearn\externals\joblib\externals\loky\reusable_executor.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky
#   copying sklearn\externals\joblib\externals\loky\_base.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky
#   copying sklearn\externals\joblib\externals\loky\__init__.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky
#   creating build\lib.win-amd64-3.10\sklearn\externals\joblib\externals\loky\backend
#   copying sklearn\externals\joblib\externals\loky\backend\compat.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\compat_posix.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\compat_win32.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\context.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\fork_exec.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\managers.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\popen_loky_posix.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\popen_loky_win32.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\process.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\queues.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\reduction.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\semaphore_tracker.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\semlock.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\spawn.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\synchronize.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\utils.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\_posix_reduction.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\_posix_wait.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\_win_reduction.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\_win_wait.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   copying sklearn\externals\joblib\externals\loky\backend\__init__.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/loky/backend
#   creating build\lib.win-amd64-3.10\sklearn\externals\joblib\externals\cloudpickle
#   copying sklearn\externals\joblib\externals\cloudpickle\cloudpickle.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/cloudpickle
#   copying sklearn\externals\joblib\externals\cloudpickle\__init__.py -> build\lib.win-amd64-3.10\sklearn\externals\joblib/externals/cloudpickle
#   creating build\lib.win-amd64-3.10\sklearn\feature_extraction
#   copying sklearn\feature_extraction\dict_vectorizer.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction
#   copying sklearn\feature_extraction\hashing.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction
#   copying sklearn\feature_extraction\image.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction
#   copying sklearn\feature_extraction\setup.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction
#   copying sklearn\feature_extraction\stop_words.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction
#   copying sklearn\feature_extraction\text.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction
#   copying sklearn\feature_extraction\__init__.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction
#   creating build\lib.win-amd64-3.10\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_dict_vectorizer.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_feature_hasher.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_image.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\test_text.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction\tests
#   copying sklearn\feature_extraction\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\feature_extraction\tests
#   creating build\lib.win-amd64-3.10\sklearn\manifold
#   copying sklearn\manifold\isomap.py -> build\lib.win-amd64-3.10\sklearn\manifold
#   copying sklearn\manifold\locally_linear.py -> build\lib.win-amd64-3.10\sklearn\manifold
#   copying sklearn\manifold\mds.py -> build\lib.win-amd64-3.10\sklearn\manifold
#   copying sklearn\manifold\setup.py -> build\lib.win-amd64-3.10\sklearn\manifold
#   copying sklearn\manifold\spectral_embedding_.py -> build\lib.win-amd64-3.10\sklearn\manifold
#   copying sklearn\manifold\t_sne.py -> build\lib.win-amd64-3.10\sklearn\manifold
#   copying sklearn\manifold\__init__.py -> build\lib.win-amd64-3.10\sklearn\manifold
#   creating build\lib.win-amd64-3.10\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_isomap.py -> build\lib.win-amd64-3.10\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_locally_linear.py -> build\lib.win-amd64-3.10\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_mds.py -> build\lib.win-amd64-3.10\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_spectral_embedding.py -> build\lib.win-amd64-3.10\sklearn\manifold\tests
#   copying sklearn\manifold\tests\test_t_sne.py -> build\lib.win-amd64-3.10\sklearn\manifold\tests
#   copying sklearn\manifold\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\manifold\tests
#   creating build\lib.win-amd64-3.10\sklearn\metrics
#   copying sklearn\metrics\base.py -> build\lib.win-amd64-3.10\sklearn\metrics
#   copying sklearn\metrics\classification.py -> build\lib.win-amd64-3.10\sklearn\metrics
#   copying sklearn\metrics\pairwise.py -> build\lib.win-amd64-3.10\sklearn\metrics
#   copying sklearn\metrics\ranking.py -> build\lib.win-amd64-3.10\sklearn\metrics
#   copying sklearn\metrics\regression.py -> build\lib.win-amd64-3.10\sklearn\metrics
#   copying sklearn\metrics\scorer.py -> build\lib.win-amd64-3.10\sklearn\metrics
#   copying sklearn\metrics\setup.py -> build\lib.win-amd64-3.10\sklearn\metrics
#   copying sklearn\metrics\__init__.py -> build\lib.win-amd64-3.10\sklearn\metrics
#   creating build\lib.win-amd64-3.10\sklearn\metrics\cluster
#   copying sklearn\metrics\cluster\bicluster.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster
#   copying sklearn\metrics\cluster\setup.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster
#   copying sklearn\metrics\cluster\supervised.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster
#   copying sklearn\metrics\cluster\unsupervised.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster
#   copying sklearn\metrics\cluster\__init__.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster
#   creating build\lib.win-amd64-3.10\sklearn\metrics\cluster\tests
#   copying sklearn\metrics\cluster\tests\test_bicluster.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster\tests
#   copying sklearn\metrics\cluster\tests\test_common.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster\tests
#   copying sklearn\metrics\cluster\tests\test_supervised.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster\tests
#   copying sklearn\metrics\cluster\tests\test_unsupervised.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster\tests
#   copying sklearn\metrics\cluster\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\metrics\cluster\tests
#   creating build\lib.win-amd64-3.10\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_classification.py -> build\lib.win-amd64-3.10\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_common.py -> build\lib.win-amd64-3.10\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_pairwise.py -> build\lib.win-amd64-3.10\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_ranking.py -> build\lib.win-amd64-3.10\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_regression.py -> build\lib.win-amd64-3.10\sklearn\metrics\tests
#   copying sklearn\metrics\tests\test_score_objects.py -> build\lib.win-amd64-3.10\sklearn\metrics\tests
#   copying sklearn\metrics\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\metrics\tests
#   creating build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\approximate.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\base.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\classification.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\graph.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\kde.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\lof.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\nearest_centroid.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\regression.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\setup.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\unsupervised.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   copying sklearn\neighbors\__init__.py -> build\lib.win-amd64-3.10\sklearn\neighbors
#   creating build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_approximate.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_ball_tree.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_dist_metrics.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_kde.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_kd_tree.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_lof.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_nearest_centroid.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_neighbors.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\test_quad_tree.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   copying sklearn\neighbors\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\neighbors\tests
#   creating build\lib.win-amd64-3.10\sklearn\tree
#   copying sklearn\tree\export.py -> build\lib.win-amd64-3.10\sklearn\tree
#   copying sklearn\tree\setup.py -> build\lib.win-amd64-3.10\sklearn\tree
#   copying sklearn\tree\tree.py -> build\lib.win-amd64-3.10\sklearn\tree
#   copying sklearn\tree\__init__.py -> build\lib.win-amd64-3.10\sklearn\tree
#   creating build\lib.win-amd64-3.10\sklearn\tree\tests
#   copying sklearn\tree\tests\test_export.py -> build\lib.win-amd64-3.10\sklearn\tree\tests
#   copying sklearn\tree\tests\test_tree.py -> build\lib.win-amd64-3.10\sklearn\tree\tests
#   copying sklearn\tree\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\tree\tests
#   creating build\lib.win-amd64-3.10\sklearn\svm
#   copying sklearn\svm\base.py -> build\lib.win-amd64-3.10\sklearn\svm
#   copying sklearn\svm\bounds.py -> build\lib.win-amd64-3.10\sklearn\svm
#   copying sklearn\svm\classes.py -> build\lib.win-amd64-3.10\sklearn\svm
#   copying sklearn\svm\setup.py -> build\lib.win-amd64-3.10\sklearn\svm
#   copying sklearn\svm\__init__.py -> build\lib.win-amd64-3.10\sklearn\svm
#   creating build\lib.win-amd64-3.10\sklearn\svm\tests
#   copying sklearn\svm\tests\test_bounds.py -> build\lib.win-amd64-3.10\sklearn\svm\tests
#   copying sklearn\svm\tests\test_sparse.py -> build\lib.win-amd64-3.10\sklearn\svm\tests
#   copying sklearn\svm\tests\test_svm.py -> build\lib.win-amd64-3.10\sklearn\svm\tests
#   copying sklearn\svm\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\svm\tests
#   creating build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\base.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\bayes.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\coordinate_descent.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\huber.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\least_angle.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\logistic.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\omp.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\passive_aggressive.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\perceptron.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\randomized_l1.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\ransac.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\ridge.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\sag.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\setup.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\stochastic_gradient.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\theil_sen.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   copying sklearn\linear_model\__init__.py -> build\lib.win-amd64-3.10\sklearn\linear_model
#   creating build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_base.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_bayes.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_coordinate_descent.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_huber.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_least_angle.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_logistic.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_omp.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_passive_aggressive.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_perceptron.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_randomized_l1.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_ransac.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_ridge.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sag.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sgd.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_sparse_coordinate_descent.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\test_theil_sen.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   copying sklearn\linear_model\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\linear_model\tests
#   creating build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\arpack.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\bench.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\class_weight.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\deprecation.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\estimator_checks.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\extmath.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\fixes.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\graph.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\linear_assignment_.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\metaestimators.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\mocking.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\multiclass.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\optimize.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\random.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\setup.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\sparsefuncs.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\stats.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\testing.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\validation.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\_joblib.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\_scipy_sparse_lsqr_backport.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\_show_versions.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\_unittest_backport.py -> build\lib.win-amd64-3.10\sklearn\utils
#   copying sklearn\utils\__init__.py -> build\lib.win-amd64-3.10\sklearn\utils
#   creating build\lib.win-amd64-3.10\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\setup.py -> build\lib.win-amd64-3.10\sklearn\utils\sparsetools
#   copying sklearn\utils\sparsetools\__init__.py -> build\lib.win-amd64-3.10\sklearn\utils\sparsetools
#   creating build\lib.win-amd64-3.10\sklearn\utils\sparsetools\tests
#   copying sklearn\utils\sparsetools\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\utils\sparsetools\tests
#   creating build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_bench.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_class_weight.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_deprecation.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_estimator_checks.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_extmath.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_fast_dict.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_fixes.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_graph.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_linear_assignment.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_metaestimators.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_multiclass.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_murmurhash.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_optimize.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_random.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_seq_dataset.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_shortest_path.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_show_versions.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_sparsefuncs.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_stats.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_testing.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_utils.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\test_validation.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   copying sklearn\utils\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\utils\tests
#   creating build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_base.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_calibration.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_check_build.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_common.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_config.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_discriminant_analysis.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_docstring_parameters.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_dummy.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_impute.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_init.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_isotonic.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_kernel_approximation.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_kernel_ridge.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_metaestimators.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_multiclass.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_multioutput.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_naive_bayes.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_pipeline.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_random_projection.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\test_site_joblib.py -> build\lib.win-amd64-3.10\sklearn\tests
#   copying sklearn\tests\__init__.py -> build\lib.win-amd64-3.10\sklearn\tests
#   running build_clib
#   INFO: No module named 'numpy.distutils._msvccompiler' in numpy.distutils; trying from distutils
#   INFO: customize MSVCCompiler
#   WARN: Missing compiler_cxx fix for MSVCCompiler
#   INFO: customize MSVCCompiler using build_clib
#   INFO: CCompilerOpt.cc_test_flags[1021] : testing flags (/O2)
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   INFO: CCompilerOpt.cache_flush[817] : write cache to path -> C:\Users\User\AppData\Local\Temp\pip-install-tkl58ecs\scikit-learn_d4f8ac20f4804a1fa2ee8f26b8428238\build\temp.win-amd64-3.10\ccompiler_opt_cache_clib.py
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# scikit-learn
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six

# %%
pip install pydotplus
# Out:
# Collecting pydotplus
#   Downloading pydotplus-2.0.2.tar.gz (278 kB)
#      ------------------------------------ 278.7/278.7 kB 818.4 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\user\appdata\local\programs\python\python310\lib\site-packages (from pydotplus) (3.0.7)
# Installing collected packages: pydotplus
#   Running setup.py install for pydotplus: started
#   Running setup.py install for pydotplus: finished with status 'done'
# Successfully installed pydotplus-2.0.2
# Note: you may need to restart the kernel to use updated packages.
#   DEPRECATION: pydotplus is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559

# %%
pip install graphviz
# Out:
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      -------------------------------------- 47.0/47.0 kB 261.0 kB/s eta 0:00:00
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Out:
#     animal_name  hair  feathers  eggs  milk  airborne  aquatic  predator  \
# 0      aardvark     1         0     0     1         0        0         1
# 1      antelope     1         0     0     1         0        0         0
# 2          bass     0         0     1     0         0        1         1
# 3          bear     1         0     0     1         0        0         1
# 4          boar     1         0     0     1         0        0         1
# ..          ...   ...       ...   ...   ...       ...      ...       ...
# 96      wallaby     1         0     0     1         0        0         0
# 97         wasp     1         0     1     0         1        0         0
# 98         wolf     1         0     0     1         0        0         1
# 99         worm     0         0     1     0         0        0         0
# 100        wren     0         1     1     0         1        0         0
#
#      toothed  backbone  breathes  venomous  fins  legs  tail  domestic  \
# 0          1         1         1         0     0     4     0         0
# 1          1         1         1         0     0     4     1         0
# 2          1         1         0         0     1     0     1         0
# 3          1         1         1         0     0     4     0         0
# 4          1         1         1         0     0     4     1         0
# ..       ...       ...       ...       ...   ...   ...   ...       ...
# 96         1         1         1         0     0     2     1         0
# 97         0         0         1         1     0     6     0         0
# 98         1         1         1         0     0     4     1         0
# 99         0         0         1         0     0     0     0         0
# 100        0         1         1         0     0     2     1         0
#
#      catsize  class_type
# 0          1           1
# 1          1           1
# 2          0           4
# 3          1           1
# 4          1           1
# ..       ...         ...
# 96         1           1
# 97         0           6
# 98         1           1
# 99         0           7
# 100        0           2
#
# [101 rows x 18 columns]

# %%
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 96     0
# 97     1
# 98     0
# 99     0
# 100    0
# Name: venomous, Length: 101, dtype: int64
